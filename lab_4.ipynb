# %% [markdown]
# # Matrix(list of list)

# %%
m=[
    [10,20],
    [30,40],
    [50,60]
]

print(m)
print(type(m))
print(len(m))
print(m[1])
print(len(m[0]))
# Out:
# [[10, 20], [30, 40], [50, 60]]
# <class 'list'>
# 3
# [30, 40]
# 2

# %%
row=len(m)
col=len(m[0])
for in range():
    for j in range(len(m[0])):
        print(m[i][j],end=" ")
    print()
# Out:
#   Cell In[5], line 1
#     for in range(len(m)):
#         ^
# SyntaxError: invalid syntax
