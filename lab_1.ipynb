# %%
print("Hello")
# Out:
# Hello

# %%
print("I Love Python")
print("I Love Bangladesh")
# Out:
# I Love Python
# I Love Bangladesh

# %% [markdown]
# # Python Basic
# --------------------
# 1. data types and variable
#     > int, float,
#     > Boolean
# 2. Expression and operator

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=0.8
print(type(b))
print(b)
# Out:
# <class 'float'>
# 0.8

# %%
c=True
print(type(c))
print(c)
# Out:
# <class 'bool'>
# True

# %%
str="I Love Python"
print(str)
print(type(str))
print(len(str))
# Out:
# I Love Python
# <class 'str'>
# 13

# %%
str1=str.lower()
print(str1)
# Out:
# i love python

# %%
str2=str.upper()
print(str2)
# Out:
# I LOVE PYTHON

# %%
# strip()
# replace()
# split()

str10=" I Love AI "
print(len(str10))
str11=str10.strip()
print(str11)
print(len(str11))


str12=str10.replace("I","We")
print(str12)
# Out:
# 11
# I Love AI
# 9
#  We Love AWe

# %%
str14="Welcome to AI Lab"
s=str14.split(" ")
print(s)
# Out:
# ['Welcome', 'to', 'AI', 'Lab']

# %%
str14="Welcome to AI Lab"
print(str14.count("e"))
# Out:
# 2

# %%
name="Minhaz Ul Mostofa Pranto"
print(len(name))
print(name[0])
print(name[len(name)-1])
print(name[:4])
print(name[2:7])
print(name[4:])
# Out:
# 24
# M
# o
# Minh
# nhaz
# az Ul Mostofa Pranto

# %%
st1="I Love Python\n"
print(len(st1))
st2="I love Bangladesh"
print(len(st2))
st3=st1+st2
print(st3)
print(len(st3))
# Out:
# 14
# 17
# I Love Python
# I love Bangladesh
# 31

# %%
st="a"
st=st+"A"
st=st+"B"
print(st)
# Out:
# aAB

# %%
st="a"
st+"A"
st+"B"
print(st)
# Out:
# a
